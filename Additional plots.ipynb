# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as patches
from matplotlib.patches import Polygon
import pandas as pd
data=pd.read_excel('ALL_FW_DATA.xlsx',sheet_name='all_data')
# Out:
# /Users/oliviawren/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
idx1 = data['FW_']=='FW_1'
idx2 = data['FW_']=='FW_2'
idx3 = data['FW_']=='FW_3'
idx4 = data['FW_']=='FW_4'
idx5 = data['FW_']=='FW_5'
idx6 = data['FW_']=='FW_6'
idx7 = data['FW_']=='FW_7'

y=data['relative_height']
x=data['d13c']

plt.figure(figsize=(12,25.6))

plt.scatter(x[idx1],y[idx1],label='1',color='#2a9d8f',s=90)
plt.scatter(x[idx2],y[idx2],label='2',color='#f07167',s=90)
plt.scatter(x[idx4],y[idx4],label='4',color='#9d4edd',s=90)
plt.scatter(x[idx3],y[idx3],label='3',color='#ff9100',s=90)
plt.scatter(x[idx5],y[idx5],label='5',color='#f3de2c',s=90)
plt.scatter(x[idx6],y[idx6],label='6',color='#80b918',s=90)
plt.scatter(x[idx7],y[idx7],label='7',color='#723d46',s=90)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

#723d46
#90a955
#f7a072
#118ab2
#f07167

plt.xlabel('$\delta^{13}$C',fontsize=45)
plt.ylabel('Stratigraphic height (m)',fontsize=45)

plt.xlim(-4,4)

plt.legend(loc='upper left',fontsize=25,frameon=True)
plt.savefig('1_composite_c.pdf')

# %%
y=data['relative_height']
x=data['d13c']
idx=data['plat_pre']=='pre'

plt.figure(figsize=(12,25.6))

plt.scatter(x[idx1&idx],y[idx1&idx],label='1',color='#2a9d8f',s=90)
plt.scatter(x[idx2&idx],y[idx2&idx],label='2',color='#f07167',s=90)
plt.scatter(x[idx4&idx],y[idx4&idx],label='4',color='#9d4edd',s=90)
plt.scatter(x[idx3&idx],y[idx3&idx],label='3',color='#ff9100',s=90)
plt.scatter(x[idx5&idx],y[idx5&idx],label='5',color='#f3de2c',s=90)
plt.scatter(x[idx6&idx],y[idx6&idx],label='6',color='#80b918',s=90)
plt.scatter(x[idx7&idx],y[idx7&idx],label='7',color='#723d46',s=90)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

#723d46
#90a955
#f7a072
#118ab2
#f07167

plt.xlabel('$\delta^{13}$C',fontsize=45)
plt.ylabel('Stratigraphic height (m)',fontsize=45)

plt.xlim(-4,4)

plt.legend(loc='upper left',fontsize=25,frameon=True)
plt.savefig('composite_c_pre.pdf')

# %%
y=data['relative_height']
x=data['d13c']


plt.figure(figsize=(12,25.6))

plt.scatter(x[idx1],y[idx1],label='1',color='#2a9d8f',s=90)
plt.scatter(x[idx2],y[idx2],label='2',color='#f07167',s=90)
plt.scatter(x[idx4],y[idx4],label='4',color='#9d4edd',s=90)
plt.scatter(x[idx3],y[idx3],label='3',color='#ff9100',s=90)
plt.scatter(x[idx5],y[idx5],label='5',color='#f3de2c',s=90)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

#723d46
#90a955
#f7a072
#118ab2
#f07167

plt.xlabel('$\delta^{13}$C',fontsize=45)
plt.ylabel('Stratigraphic height (m)',fontsize=45)

plt.xlim(-4,4)

plt.legend(loc='upper left',fontsize=25,frameon=True)
plt.savefig('2_composite_c_pre.pdf')

# %%
plt.figure(figsize=(12,18))

plt.scatter(x[idx1],y[idx1],label='1',color='#2a9d8f',s=90)
plt.scatter(x[idx2],y[idx2],label='2',color='#f07167',s=90)
plt.scatter(x[idx6],y[idx6],label='6',color='#80b918',s=90)
plt.scatter(x[idx7],y[idx7],label='7',color='#723d46',s=90)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

#723d46
#90a955
#f7a072
#118ab2
#f07167

plt.xlabel('$\delta^{13}$C',fontsize=45)
plt.ylabel('Stratigraphic height (m)',fontsize=45)

plt.xlim(-4,4)
plt.ylim(0,250)

plt.legend(loc='upper left',fontsize=25,frameon=True)
plt.savefig('1267_composite_c.pdf')

# %%
idx1 = data['FW_']=='FW_1'
idx2 = data['FW_']=='FW_2'
idx3 = data['FW_']=='FW_3'
idx4 = data['FW_']=='FW_4'
idx5 = data['FW_']=='FW_5'
idx6 = data['FW_']=='FW_6'
idx7 = data['FW_']=='FW_7'

y=data['relative_height']
x=data['d13c']

plt.figure(figsize=(12,25.6))

plt.scatter(x[idx1],y[idx1],label='FW 1',color='#2a9d8f',s=90)
plt.scatter(x[idx2],y[idx2],label='FW 2',color='#f07167',s=90)
plt.scatter(x[idx4],y[idx4],label='FW 4',color='#9d4edd',s=90)
plt.scatter(x[idx3],y[idx3],label='FW 3',color='#ff9100',s=90)
plt.scatter(x[idx5],y[idx5],label='FW 5',color='#80b918',s=90)
plt.scatter(x[idx6],y[idx6],label='FW 6',color='#f3de2c',s=90)
plt.scatter(x[idx7],y[idx7],label='FW 7',color='#723d46',s=90)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

#723d46
#90a955
#f7a072
#118ab2
#f07167

plt.xlabel('$\delta^{13}$C',fontsize=45)
plt.ylabel('Stratigraphic height (m)',fontsize=45)

plt.xlim(-4,4)

plt.legend(loc='upper left',fontsize=25,frameon=True)
plt.savefig('old_composite_c.pdf')

# %%
idx = (data['lithology']=='siliciclastic') 
idx2 = data['pp']=='plat'
idx3 = (data['FW-']=='FW6') | (data['FW-']=='FW7')
#sili thickness
a=np.sum(data['thickness'][idx&idx2&idx3])
print(a)
#total thickness
b=np.sum(data['thickness'][idx2&idx3])
print(b)
c=(a/b)*100
print('FW6/7 %silici in plat',c)

idx3 = (data['FW-']=='FW1') | (data['FW-']=='FW2')
#sili thickness
a=np.sum(data['thickness'][idx&idx2&idx3])
print(a)
#total thickness
b=np.sum(data['thickness'][idx2&idx3])
print(b)
c=(a/b)*100
print('FW1/2 %silici in plat',c)
# Out:
# 42.199999999999996
# 101.6
# FW6/7 %silici in plat 41.53543307086614
# 17.700000000000003
# 416.90000000000003
# FW1/2 %silici in plat 4.2456224514272005

# %%
idx = (data['lithology']=='siliciclastic') 
idx2 = data['pp']=='plat'
idx3 = data['pp']=='pre'
a=np.sum(data['thickness'][idx&idx2])
print(a)
#total thickness
b=np.sum(data['thickness'][idx2])
print(b)
c=(a/b)*100
print(c, '%silici in all plat')

a=np.sum(data['thickness'][idx&idx3])
print(a)
#total thickness
b=np.sum(data['thickness'][idx3])
print(b)
c=(a/b)*100
print(c, '%silici in all pre')

idx = (data['lithology']=='siliciclastic') 
idx2 = data['pp']=='plat'
idx3 = (data['FW-']=='FW6') | (data['FW-']=='FW7')
#sili thickness
a=np.sum(data['thickness'][idx&idx2&idx3])
b=np.sum(data['thickness'][idx&idx2])
(print(a))
print(b)
c=(a/b)*100
print(c)
# Out:
# 59.9
# 518.5
# 11.55255544840887 %silici in all plat
# 90.5
# 403.5
# 22.428748451053284 %silici in all pre
# 42.199999999999996
# 59.9
# 70.4507512520868

# %%
#Variability in d13C:
print('overall variability in d13C: ',np.min(data['d13c']),np.max(data['d13c']))
idx=data['d13c']>-11
print('excluding outlier: ',np.min(data['d13c'][idx]),np.max(data['d13c']))
idx=data['FW_']=='FW_1'
print('FW1 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx2=data['plat_pre']=='pre'
print('FW1 d13C variability pre-platform: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW1 d13C variability platform: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_2'
print('FW2 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx2=data['plat_pre']=='pre'
print('FW2 d13C variability pre-platform: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW2 d13C variability platform: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_3'
print('FW3 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx2=data['lith']=='stromatolite bioherm'
print('FW3 d13C variability (bioherm): ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_4'
print('FW4 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx2=data['lith']=='stromatolite bioherm'
print('FW4 d13C variability (bioherm): ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_5'
print('FW5 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx2=data['d13c']>-11
print('FW5 d13C variability exclusing outlier: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx]))
idx=data['FW_']=='FW_6'
print('FW6 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
idx=data['FW_']=='FW_7'
print('FW7 d13C variability: ',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
# Out:
# overall variability in d13C:  -11.9578886032104 3.797496796
# excluding outlier:  -3.8012843132019 3.797496796
# FW1 d13C variability:  -2.695728064 3.797496796
# FW1 d13C variability pre-platform:  -2.695728064 1.153045654
# FW1 d13C variability platform:  -0.413389683 3.797496796
# FW2 d13C variability:  -0.41725111 3.138842106
# FW2 d13C variability pre-platform:  0.162417412 0.504714012
# FW2 d13C variability platform:  -0.41725111 3.138842106
# FW3 d13C variability:  -0.441625118 1.339696407
# FW3 d13C variability (bioherm):  -0.441625118 1.339696407
# FW4 d13C variability:  -3.62809562683105 1.34752464294433
# FW4 d13C variability (bioherm):  -0.27557373046875 1.34752464294433
# FW5 d13C variability:  -11.9578886032104 0.436403751373291
# FW5 d13C variability exclusing outlier:  -3.8012843132019 0.436403751373291
# FW6 d13C variability:  -2.52098751068115 1.61194419860839
# FW7 d13C variability:  -1.06520462036132 0.178176879882812

# %%
#Variability in d18O:
print('overall mean d18O: ',np.mean(data['d18o']))
print('overall variability in d13C: ',np.min(data['d18o']),np.max(data['d18o']))
idx=data['FW_']=='FW_1'
print('FW1 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx2=data['plat_pre']=='pre'
print('FW1 d18o variability pre-platform: ',np.min(data['d18o'][idx&idx2]),np.max(data['d18o'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW1 d18o variability platform: ',np.min(data['d18o'][idx&idx2]),np.max(data['d18o'][idx&idx2]))
idx=data['FW_']=='FW_2'
print('FW2 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx2=data['plat_pre']=='pre'
print('FW2 d18o variability pre-platform: ',np.min(data['d18o'][idx&idx2]),np.max(data['d18o'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW2 d18o variability platform: ',np.min(data['d18o'][idx&idx2]),np.max(data['d18o'][idx&idx2]))
idx=data['FW_']=='FW_3'
print('FW3 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx=data['FW_']=='FW_4'
print('FW4 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx=data['FW_']=='FW_5'
print('FW5 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx=data['FW_']=='FW_6'
print('FW6 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
idx=data['FW_']=='FW_7'
print('FW7 d18o variability: ',np.min(data['d18o'][idx]),np.max(data['d18o'][idx]))
# Out:
# overall mean d18O:  -5.394540336523083
# overall variability in d13C:  -15.1556034088134 -0.141942978
# FW1 d18o variability:  -10.69867516 -1.574501038
# FW1 d18o variability pre-platform:  -10.69867516 -2.125431061
# FW1 d18o variability platform:  -9.447242737 -1.574501038
# FW2 d18o variability:  -10.01547337 -3.13469696
# FW2 d18o variability pre-platform:  -8.251617432 -4.622272491
# FW2 d18o variability platform:  -10.01547337 -3.13469696
# FW3 d18o variability:  -7.109247208 -0.141942978
# FW4 d18o variability:  -12.5121221542358 -1.26811218261718
# FW5 d18o variability:  -14.6758728027343 -2.70984077453613
# FW6 d18o variability:  -15.1556034088134 -1.64235305786132
# FW7 d18o variability:  -7.28169631958007 -1.64208984375

# %%
#mean values:
print('overall mean d13C: ',np.mean(data['d13c']))
idx=data['d13c']>-11
print('excluding outlier: ',np.mean(data['d13c'][idx]))
idx=data['FW_']=='FW_1'
print('FW1 d13C mean: ',np.mean(data['d13c'][idx]))
idx2=data['plat_pre']=='pre'
print('FW1 d13C mean pre-platform: ',np.mean(data['d13c'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW1 d13C mean platform: ',np.mean(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_2'
print('FW2 d13C variability: ',np.mean(data['d13c'][idx]))
idx2=data['plat_pre']=='pre'
print('FW2 d13C mean pre-platform: ',np.mean(data['d13c'][idx&idx2]))
idx2=data['plat_pre']=='plat'
print('FW2 d13C mean platform: ',np.mean(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_3'
print('FW3 d13C mean: ',np.mean(data['d13c'][idx]))
idx=data['FW_']=='FW_4'
print('FW4 d13C mean: ',np.mean(data['d13c'][idx]))
idx=data['FW_']=='FW_5'
print('FW5 d13C mean: ',np.mean(data['d13c'][idx]))
idx2=data['d13c']>-11
print('FW5 mean excluding outlier: ',np.mean(data['d13c'][idx&idx2]))
idx=data['FW_']=='FW_6'
print('FW6 d13C mean: ',np.mean(data['d13c'][idx]))
idx=data['FW_']=='FW_7'
print('FW7 d13C mean: ',np.mean(data['d13c'][idx]))
# Out:
# overall mean d13C:  0.7366935484717972
# excluding outlier:  0.7611532443324566
# FW1 d13C mean:  1.380630289995653
# FW1 d13C mean pre-platform:  -0.972872809368421
# FW1 d13C mean platform:  1.5925571093696689
# FW2 d13C variability:  0.7588653118702292
# FW2 d13C mean pre-platform:  0.0512060325
# FW2 d13C mean platform:  0.79283295728
# FW3 d13C mean:  0.842273146962963
# FW4 d13C mean:  -0.015040066184067797
# FW5 d13C mean:  -2.201693632385941
# FW5 mean excluding outlier:  -1.7371129194895385
# FW6 d13C mean:  -0.0008951402177996837
# FW7 d13C mean:  -0.41763875219556945

# %%
idx1=(data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx2=(data['FW_']=='FW_6') | (data['FW_']=='FW_7')
print('FW1/2 d13C mean: ',np.mean(data['d13c'][idx1]))
print('FW6/7 d13C mean: ',np.mean(data['d13c'][idx2]))
# Out:
# FW1/2 d13C mean:  1.155003663584488
# FW6/7 d13C mean:  -0.10961086508156571

# %%
idx=data['plat_pre']=='pre'
idx2=data['d13c']>-11
print('d13C range, pre-plat, all data:',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx]))
print('pre-plat mean, all data: ',np.mean(data['d13c'][idx&idx2]))
idx3=data['lith']!='stromatolite bioherm'
print('d13C range, pre-plat, all data, no bioherm:',np.min(data['d13c'][idx&idx2&idx3]),np.max(data['d13c'][idx&idx3]))
print('pre-plat mean, all data, no bioherm: ',np.mean(data['d13c'][idx&idx2&idx3]))
idx3=data['lith']=='stromatolite bioherm'
print('mean, all data, bioherm: ',np.mean(data['d13c'][idx&idx3]))

idx=data['plat_pre']=='plat'
print('d13C range, plat, all data:',np.min(data['d13c'][idx]),np.max(data['d13c'][idx]))
print('plat mean, all data: ',np.mean(data['d13c'][idx&idx2]))

idx=data['plat_pre']=='pre'
idx2=data['lith']!='stromatolite bioherm'
idx3=(data['FW_']=='FW_3') | (data['FW_']=='FW_4')
print('FW3/4 d13C mean- no bioherm: ',np.mean(data['d13c'][idx&idx2&idx3]))
# Out:
# d13C range, pre-plat, all data: -3.8012843132019 1.34752464294433
# pre-plat mean, all data:  -0.28536830033181654
# d13C range, pre-plat, all data, no bioherm: -3.8012843132019 1.153045654
# pre-plat mean, all data, no bioherm:  -1.313729425952538
# mean, all data, bioherm:  0.7797200083467875
# d13C range, plat, all data: -2.52098751068115 3.797496796
# plat mean, all data:  1.0557296791268445
# FW3/4 d13C mean- no bioherm:  -1.7949656844139066

# %%
print('bioherm shiznit')
idx=data['FW_']=='FW_4'
idx2=data['lith']!='stromatolite bioherm'
idx3=data['lith']=='stromatolite bioherm'

print('FW4 range, no bioherm: ',np.min(data['d13c'][idx&idx2]),np.max(data['d13c'][idx&idx2]))
print('FW4 range, only bioherm: ',np.min(data['d13c'][idx&idx3]),np.max(data['d13c'][idx&idx3]))
print('FW4 mean, no bioherm: ',np.mean(data['d13c'][idx&idx2]))
print('FW4 mean, only bioherm: ',np.mean(data['d13c'][idx&idx3]))

idx=(data['FW_']=='FW_4') | (data['FW_']=='FW_3')
print('FW3/4 range, only bioherm: ',np.min(data['d13c'][idx&idx3]),np.max(data['d13c'][idx&idx3]))
print('FW4/4 mean, only bioherm: ',np.mean(data['d13c'][idx&idx3]))

idx=(data['FW_']=='FW_4') | (data['FW_']=='FW_5')
idx3=data['d13c']>-11

print('FW4/5 range, no bioherm: ',np.min(data['d13c'][idx&idx2&idx3]),np.max(data['d13c'][idx&idx2&idx3]))
print('FW4/5 mean, no bioherm: ',np.mean(data['d13c'][idx&idx2&idx3]))

idx=data['FW_']=='FW_1'
idx2=data['lith']!='stromatolite bioherm'
idx3=data['lith']=='stromatolite bioherm'
print('FW1 bioherm range: ', np.min(data['d13c'][idx&idx3]),np.max(data['d13c'][idx&idx3]))
print('FW1 bioherm mean: ',np.mean(data['d13c'][idx&idx3]))
# Out:
# bioherm shiznit
# FW4 range, no bioherm:  -3.62809562683105 -0.537940502166748
# FW4 range, only bioherm:  -0.27557373046875 1.34752464294433
# FW4 mean, no bioherm:  -1.7949656844139066
# FW4 mean, only bioherm:  0.7214808792903484
# FW3/4 range, only bioherm:  -0.441625118 1.34752464294433
# FW4/4 mean, only bioherm:  0.7797200083467875
# FW4/5 range, no bioherm:  -3.8012843132019 0.436403751373291
# FW4/5 mean, no bioherm:  -1.758150288552945
# FW1 bioherm range:  1.435524464 3.127051353
# FW1 bioherm mean:  2.3063170570000002

# %%
#d13C histogram
plt.figure(figsize=(10,8))
xaxis=np.arange(-4,4,0.25)
plt.hist(data['d13c'],bins=xaxis,color='olivedrab')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$\delta^{13}$C$_{\mathrm{carb}}$',fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('$\delta^{13}$C$_{\mathrm{carb}}$ - all data', fontsize=25)
# plt.grid(color='grey')
plt.plot([0.734,0.734],[0,70],color='firebrick',label='Mean = 0.74 ‰ ')
plt.legend(loc='best',fontsize='xx-large',frameon=True)
plt.ylim(0,70)
# min_value = data['d13c'].min()
# max_value = data['d13c'].max()
# print(min_value)
# print(max_value)
print(np.mean(data['d13c']))
plt.savefig('d13C_hist.pdf')
# Out:
# 0.7366935484717972

# %%
#d18O histogram
# min_value = data['d18o'].min()
# max_value = data['d18o'].max()
# print(min_value)
# print(max_value)
plt.figure(figsize=(10,14))
plt.subplot(2,1,1)
xaxis=np.arange(-4,4,0.25)
plt.hist(data['d13c'],bins=xaxis,color='#84a59d')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$\delta^{13}$C$_{\mathrm{carb}}$ (‰)',fontsize=20)
plt.ylabel('Frequency',fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# plt.title('$\delta^{13}$C$_{\mathrm{carb}}$ - all data', fontsize=25)
# plt.grid(color='grey')
plt.plot([0.734,0.734],[0,70],color='k',label='Mean = 0.74 ‰ ')
plt.legend(loc='best',fontsize='xx-large',frameon=True)
plt.ylim(0,70)

plt.subplot(2,1,2)
xaxis=np.arange(-16.25,0,0.35)
plt.hist(data['d18o'],bins=xaxis,color='#e5989b')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$\delta^{18}$O$_{\mathrm{carb}}$ (‰)',fontsize=20)
plt.ylabel('Frequency',fontsize=19)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# plt.title('$\delta^{18}$O$_{\mathrm{carb}}$ - all data', fontsize=25)
# plt.grid(color='grey')
plt.plot([-5.39,-5.39],[0,60],color='k',label='Mean = $-$5.39 ‰ ')
plt.legend(loc='best',fontsize='xx-large',frameon=True)
plt.ylim(0,60)

print(np.mean(data['d18o']))
plt.savefig('CO_hists.pdf')
# Out:
# -5.394540336523083

# %%
idx1 = data['FW_']=='FW_1'
idx2 = data['FW_']=='FW_2'
idx3=data['plat_pre']=='pre'
idx4=data['plat_pre']=='plat'
idx5 = (data['FW_']=='FW_1') | (data['FW_']=='FW_2')
x=data['d18o']
y=data['d13c']

plt.figure(figsize=(8,8))

plt.scatter(x[idx5&idx4],y[idx5&idx4],label='FW 1&2, platform',color='#2a9d8f')
plt.scatter(x[idx5&idx3],y[idx5&idx3],label='FW 1/2, pre-platform',color='#f4a261')
# plt.scatter(x[idx1&idx3],y[idx1&idx3],label='FW 1, pre-platform',color='#f4a261')
# plt.scatter(x[idx1&idx4],y[idx1&idx4],label='FW 1, platform',color='pink')
# plt.scatter(x[idx2&idx3],y[idx2&idx3],label='FW 2, pre-platform',color='#2a9d8f')
# plt.scatter(x[idx2&idx4],y[idx2&idx4],label='FW 2, platform',color='cyan')
plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
# plt.ylim(-6,5)
plt.legend(loc='best',fontsize='xx-large',frameon=True)

plt.savefig('FW1-2_CO.pdf')

print('FW 1/2 pre-plat range:',np.min(data['d13c'][idx5&idx3]),np.max(data['d13c'][idx5&idx3]))
print('FW 1/2 pre-plat mean:',np.mean(data['d13c'][idx5&idx3]))
print('FW 1/2 plat range:',np.min(data['d13c'][idx5&idx4]),np.max(data['d13c'][idx5&idx4]))
print('FW 1/2 plat mean:',np.mean(data['d13c'][idx5&idx4]))
# Out:
# FW 1/2 pre-plat range: -2.695728064 1.153045654
# FW 1/2 pre-plat mean: -0.7270938873199999
# FW 1/2 plat range: -0.413389683 3.797496796
# FW 1/2 plat mean: 1.2950406837410715

# %%
idx1 = (data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx2=data['plat_pre']=='plat'
idx3 = (data['FW_']=='FW_6') | (data['FW_']=='FW_7')
x=data['d18o']
y=data['d13c']

plt.figure(figsize=(8,8))

plt.scatter(x[idx1&idx2],y[idx1&idx2],label='FW1 and FW2; platform',color='#2a9d8f')
plt.scatter(x[idx3],y[idx3],label='FW6 and FW7; platform',color='#f4a261')
# plt.scatter(x[idx1&idx3],y[idx1&idx3],label='FW 1, pre-platform',color='#f4a261')
# plt.scatter(x[idx1&idx4],y[idx1&idx4],label='FW 1, platform',color='pink')
# plt.scatter(x[idx2&idx3],y[idx2&idx3],label='FW 2, pre-platform',color='#2a9d8f')
# plt.scatter(x[idx2&idx4],y[idx2&idx4],label='FW 2, platform',color='cyan')
plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
# plt.ylim(-6,5)
plt.legend(loc='best',fontsize='xx-large',frameon=True)

print('FW1&2 platform range: ',np.min(data['d13c'][idx1&idx2]),np.max(data['d13c'][idx1&idx2]))
# Out:
# FW1&2 platform range:  -0.413389683 3.797496796

# %%
idx1 = (data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx2=data['plat_pre']=='pre'
idx3 = (data['FW_']=='FW_4') | (data['FW_']=='FW_5')
idx4=data['lith']!='stromatolite bioherm'
x=data['d18o']
y=data['d13c']

plt.figure(figsize=(8,8))

plt.scatter(x[idx1&idx2],y[idx1&idx2],label='FW1 and FW2; pre-platform',color='#2a9d8f')
plt.scatter(x[idx3&idx4],y[idx3&idx4],label='FW4 and FW5; pre-platform',color='#f4a261')
# plt.scatter(x[idx1&idx3],y[idx1&idx3],label='FW 1, pre-platform',color='#f4a261')
# plt.scatter(x[idx1&idx4],y[idx1&idx4],label='FW 1, platform',color='pink')
# plt.scatter(x[idx2&idx3],y[idx2&idx3],label='FW 2, pre-platform',color='#2a9d8f')
# plt.scatter(x[idx2&idx4],y[idx2&idx4],label='FW 2, platform',color='cyan')
plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.ylim(-6,2)
plt.legend(loc='best',fontsize='xx-large',frameon=True)

print('FW1&2 pre-platform range: ',np.min(data['d13c'][idx1&idx2]),np.max(data['d13c'][idx1&idx2]))
# Out:
# FW1&2 pre-platform range:  -2.695728064 1.153045654

# %%
#C/O cross plot- pre plat vs plat
plt.figure(figsize=(8,8))
plt.scatter(data['d18o'][data['plat_pre']=='pre'],
         data['d13c'][data['plat_pre']=='pre'],label='pre-platform')

plt.scatter(data['d18o'][data['plat_pre']=='plat'],
         data['d13c'][data['plat_pre']=='plat'],label='platform')


plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.ylim(-6,5)
plt.legend(loc='best',fontsize='xx-large',frameon=False)

# %%
idx=data['plat_pre']=='plat'
idx12=(data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx67=(data['FW_']=='FW_6') | (data['FW_']=='FW_7')
print(len(data['d18o'][idx12]))
# Out:
# 361

# %%
#C/O cross plot- pre plat vs plat + bioherm
data=pd.read_excel('ALL_FW_DATA.xlsx',sheet_name='all_data')
plt.figure(figsize=(8,8))

idx=data['plat_pre']=='plat'
idx12=(data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx67=(data['FW_']=='FW_6') | (data['FW_']=='FW_7')

plt.scatter(data['d18o'][idx&idx12],
         data['d13c'][idx&idx12],label='FW1/2 Platform',color='#a8dadc')

plt.scatter(data['d18o'][idx&idx67],
         data['d13c'][idx&idx67],label='FW6/7 Platform',color='#2a9d8f')

plt.scatter(data['d18o'][data['plat_pre']=='pre'],
         data['d13c'][data['plat_pre']=='pre'],label='Pre-platform',color='#f4a261')


plt.scatter(data['d18o'][(data['plat_pre']=='pre') & (data['lith']=='stromatolite bioherm')],
         data['d13c'][(data['plat_pre']=='pre') & (data['lith']=='stromatolite bioherm')],label='Pre-platform stromatolite bioherm',color='#f07167')

plt.xlabel('$\delta^{18}$O  (‰)',fontsize=20)
plt.ylabel('$\delta^{13}$C  (‰)',fontsize=20)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.ylim(-6.5,4)
plt.legend(loc='best',fontsize='x-large',frameon=True)

plt.savefig('c_o_facies.pdf')

#I dont think this is correc
# Out:
# /Users/oliviawren/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#C/O cross plot- pre plat vs plat + bioherm
data=pd.read_excel('ALL_FW_DATA.xlsx',sheet_name='all_data')
plt.figure(figsize=(8,8))

idxp=data['plat_pre']=='plat'
idxpp=data['plat_pre']=='pre'
idx12=(data['FW_']=='FW_1') | (data['FW_']=='FW_2')
idx67=(data['FW_']=='FW_6') | (data['FW_']=='FW_7')

plt.scatter(data['d18o'][idxp&idx12],
         data['d13c'][idxp&idx12],label='FW1/2 Platform',color='#83c5be',s=70)

plt.scatter(data['d18o'][idxpp&idx12],
         data['d13c'][idxpp&idx12],label='FW1/2 Pre-platform',color='#606c38',s=70)

plt.scatter(data['d18o'][idxp&idx67],
         data['d13c'][idxp&idx67],label='FW6/7 Platform',color='#f07167',s=70)



# plt.scatter(data['d18o'][(data['plat_pre']=='pre') & (data['lith']=='stromatolite bioherm')],
#          data['d13c'][(data['plat_pre']=='pre') & (data['lith']=='stromatolite bioherm')],label='Pre-platform stromatolite bioherm',color='#f07167')

plt.xlabel('$\delta^{18}$O (‰)',fontsize=30)
plt.ylabel('$\delta^{13}$C (‰)',fontsize=30)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=25 )
plt.tick_params(axis='x', labelsize=25 )
# plt.xticks(np.arange(-15,0,))
plt.ylim(-4,4.5)
plt.xlim(-16,-1)
plt.legend(loc='upper left',fontsize=20,frameon=True)

plt.savefig('FW_12_67_facies.pdf')
# Out:
# /Users/oliviawren/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#C/O cross plot all data: pre plat vs plat + litho

plt.figure(figsize=(13,13))

#pre-platform data
idx = (data['plat_pre']=='pre') & ((data['lith']=='stromatolite') | (data['lith']=='stromatolite bioherm')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='r',mfc='none',label='stromatolite',ms=8,mew=1.5)

idx = (data['plat_pre']=='pre') & ((data['lith']=='intraclast breccia') | (data['lith']=='breccia')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='b',mfc='none',label='breccia',ms=8,mew=1.5)

idx = (data['plat_pre']=='pre') & (data['lith']=='oncolite')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='m',mfc='none',label='oncolite',ms=8,mew=1.5)

idx = (data['plat_pre']=='pre') & (data['lith']=='grainstone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='g',mfc='none',label='grainstone',ms=8,mew=1.5)

idx = (data['plat_pre']=='pre') & (data['lith']=='sandy dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='teal',mfc='none',label='sandy dolostone',ms=8,mew=1.5)
#platform data
idx = (data['plat_pre']=='plat') & ((data['lith']=='stromatolite') | (data['lith']=='stromatolite bioherm')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='r',mfc='r',label='stromatolite',ms=9)


idx = (data['plat_pre']=='plat') & (data['lith']=='oncolite')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='m',mfc='m',label='oncolite',ms=9)


idx = (data['plat_pre']=='plat') & (data['lith']=='dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='c',mfc='c',label='dolostone',ms=9)

idx = (data['plat_pre']=='plat') & (data['lith']=='grainstone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='g',mfc='g',label='grainstone',ms=9)

idx = (data['plat_pre']=='plat') & (data['lith']=='wackestone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='brown',mfc='brown',label='wackestone',ms=9)

idx = (data['plat_pre']=='plat') & (data['lith']=='oncolitic dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'*',mec='olive',mfc='olive',label='oncolitic dolostone',ms=9)


plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.ylim(-4.5,5)
plt.legend(loc='best',fontsize='x-large',frameon=False)

# %%
set(data['lith'][data['plat_pre']=='plat'])
# Out:
# {'breccia',
#  'dolostone',
#  'grainstone',
#  'oncolite',
#  'oncolitic dolostone',
#  'stromatolite',
#  'stromatolite bioherm',
#  'wackestone'}

# %%
set(data['lith'][data['FW_']=='FW_2'])
# Out:
# {'dolostone',
#  'grainstone',
#  'oncolite',
#  'oncolitic dolostone',
#  'stromatolite',
#  'stromatolite bioherm'}

# %%
plt.figure(figsize=(10,10))
#FW3
idx = (data['FW_']=='FW_3')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='#f07167',mfc='none',label='FW3 stromatolite bioherm',ms=8,mew=1.5)
#FW4
idx = (data['FW_']=='FW_4') & (data['lith']=='stromatolite bioherm')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='#f07167',mfc='#f07167',label='FW4 stromatolite bioherm',ms=14,mew=1.5)
idx = (data['FW_']=='FW_4') & (data['lith']=='sandy dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='#118ab2',mfc='#118ab2',label='FW4 sandy dolostone',ms=14,mew=1.5)
#FW5
idx = (data['FW_']=='FW_5') & (data['lith']=='sandy dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'D',mec='#118ab2',mfc='#118ab2',label='FW5 sandy dolostone',ms=6.5,mew=1.5)
idx = (data['FW_']=='FW_5') & (data['lith']=='oncolite')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'D',mec='#f7a072',mfc='#f7a072',label='FW5 oncolite',ms=6.5,mew=1.5)
idx = (data['FW_']=='FW_5') & (data['lith']=='grainstone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'D',mec='#90a955',mfc='#90a955',label='FW5 grainstone',ms=6.5,mew=1.5)
idx = (data['FW_']=='FW_5') & (data['lith']=='intraclast breccia')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'D',mec='#723d46',mfc='#723d46',label='FW5 breccia',ms=6.5,mew=1.5)

#723d46
#90a955
#f7a072
#118ab2
#f07167


plt.xlabel('$\delta^{18}$O (‰)',fontsize=25)
plt.ylabel('$\delta^{13}$C (‰)',fontsize=25)
# plt.title('Pre platform/platform- all data',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.ylim(-4.5,2)
plt.legend(loc='best',fontsize=15,frameon=True)


plt.savefig('CO_FW3-5.pdf')

# %%
idxp=data['']

# %%
#distance to platform vs d13C

plt.figure(figsize=(10,10))
#FW1
idx = (data['FW_']=='FW_1')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'.',mec='y',mfc='y',label='FW 1',ms=14,mew=1.5)
idx = (data['FW_']=='FW_2')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'.',mec='b',mfc='b',label='FW 2',ms=14,mew=1.5)
#FW3
idx = (data['FW_']=='FW_3')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'*',mec='m',mfc='m',label='FW3 stromatolite bioherm',ms=9,mew=1.5)
#FW4
idx = (data['FW_']=='FW_4') & (data['lith']=='stromatolite bioherm')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'*',mec='r',mfc='r',label='FW4 stromatolite bioherm',ms=9,mew=1.5)
idx = (data['FW_']=='FW_4') & (data['lith']=='sandy dolostone')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'.',mec='c',mfc='c',label='FW 4',ms=14,mew=1.5)
idx = (data['FW_']=='FW_5')
plt.plot(data['d13c'][idx],
         data['dist'][idx],'.',mec='g',mfc='g',label='FW 5',ms=14,mew=1.5)

plt.ylabel('distance to platform (m)',fontsize=20)
plt.xlabel('$\delta^{13}$C',fontsize=20)
plt.title('',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.xlim(-4.5,2)
plt.legend(loc='best',fontsize='x-large',frameon=False)
plt.gca().invert_yaxis()
#plt.savefig('CO_FW3-5.pdf')

# %%
#FW 1&2 litho
plt.figure(figsize=(10,10))
#FW 1
idx = (data['FW_']=='FW_1') & ((data['lith']=='stromatolite') | (data['lith']=='stromatolite bioherm')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='r',mfc='r',label='FW1 stromatolite',ms=14,mew=1.5)
idx = (data['FW_']=='FW_1') & ((data['lith']=='oncolite') | (data['lith']=='oncolitic dolostone')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='m',mfc='m',label='FW1 oncolite',ms=14,mew=1.5)
idx = (data['FW_']=='FW_1') & (data['lith']=='dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='teal',mfc='teal',label='FW1 dolostone',ms=14,mew=1.5)
idx = (data['FW_']=='FW_1') & (data['lith']=='grainstone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='g',mfc='g',label='FW1 grainstone',ms=14,mew=1.5)
idx = (data['FW_']=='FW_1') & (data['lith']=='wackestone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'.',mec='brown',mfc='brown',label='FW1 wackestone',ms=14,mew=1.5)
#FW 2
idx = (data['FW_']=='FW_2') & ((data['lith']=='stromatolite') | (data['lith']=='stromatolite bioherm')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='r',mfc='none',label='FW2 stromatolite',ms=9,mew=1.5)
idx = (data['FW_']=='FW_2') & ((data['lith']=='oncolite') | (data['lith']=='oncolitic dolostone')) 
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='m',mfc='none',label='FW2 oncolite',ms=9,mew=1.5)
idx = (data['FW_']=='FW_2') & (data['lith']=='dolostone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='teal',mfc='none',label='FW2 dolostone',ms=9,mew=1.5)
idx = (data['FW_']=='FW_2') & (data['lith']=='grainstone')
plt.plot(data['d18o'][idx],
         data['d13c'][idx],'o',mec='g',mfc='none',label='FW2 grainstone',ms=9,mew=1.5)

plt.xlabel('$\delta^{18}$O',fontsize=20)
plt.ylabel('$\delta^{13}$C',fontsize=20)
plt.title('Litho FW 1 & 2',fontsize=20)
plt.tick_params(axis='y', labelsize=15 )
plt.tick_params(axis='x', labelsize=15 )
plt.legend(loc='best',fontsize='x-large',frameon=False)
